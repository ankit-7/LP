# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

df = pd.read_csv('BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# df.drop(columns=['CAT. MEDV'],inplace=True)
# df.dropna(inplace=True)
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.corr()['medv'].sort_values()
# Out:
# lstat     -0.737663
# ptratio   -0.507787
# indus     -0.483725
# tax       -0.468536
# nox       -0.427321
# crim      -0.388305
# rad       -0.381626
# age       -0.376955
# chas       0.175260
# dis        0.249929
# b          0.333461
# zn         0.360445
# rm         0.695360
# medv       1.000000
# Name: medv, dtype: float64

# %%
X = df.loc[:, df.columns != 'medv'].values  #or X = df.loc[:,['lstat','ptratio','rm]]
y = df.loc[:, df.columns == 'medv'].values  #or y = df.loc[:,'medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %% [markdown]
# ### Normalizing Training and Testing Data Set

# %%
scaler = StandardScaler() #standardise (Z-score normalization => mean = 0 and Std = 1)
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##### input_shape=(13,): This parameter defines the shape of the input data for the first layer. In this case, it expects input data with 13 features.
# ##### activation='relu': This parameter specifies the activation function to be used in the layer. Activation functions introduce non-linearity to the network, enabling it to learn complex patterns. In this case, the Rectified Linear Unit (ReLU) activation function is used, which returns the input if it is positive and 0 otherwise.
# ##### optimizer='adam': This parameter specifies the optimization algorithm used during training. Adam (Adaptive Moment Estimation) is a popular optimization algorithm known for its efficiency and effectiveness in a wide range of deep learning tasks.
#
# ##### loss='mse': This parameter defines the loss function used to measure the difference between the predicted output and the true output during training. MSE (Mean Squared Error) is a common loss function for regression tasks that calculates the average squared difference between the predicted and true values.
#
# ##### metrics=['mae']: This parameter specifies the evaluation metric(s) used to monitor the model's performance during training. MAE (Mean Absolute Error) is a metric that measures the average absolute difference between the predicted and true values. It provides a measure of the model's accuracy.

# %% [markdown]
# ``` Adam optimizer dynamically adjusts the learning rates for individual parameters in a neural network based on the history of gradients. This adaptive learning rate strategy helps improve the efficiency and robustness of the optimization process during training. ```

# %%
model = Sequential(layers=[Dense(128, input_shape=(13, ), activation='relu', name='dense_1'),Dense(64, activation='relu', name='dense_2'),Dense(1, activation='linear', name='dense_output')])


# model.add(Dense(128, input_shape=(13, ), activation='relu', name='dense_1'))
# model.add(Dense(64, activation='relu', name='dense_2'))
# model.add(Dense(1, activation='linear', name='dense_output'))

model.compile(optimizer='adam', loss='mse',metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 128)               1792
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_output (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 10,113
# Trainable params: 10,113
# Non-trainable params: 0
# _________________________________________________________________
# 2023-05-24 23:55:11.921584: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.fit(X_train, y_train, epochs=100, validation_split=0.05, verbose = 'auto')
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 24ms/step - loss: 552.7080 - mae: 21.8190 - val_loss: 406.5335 - val_mae: 17.3947
# Epoch 2/100
# 12/12 [==============================] - 0s 4ms/step - loss: 476.3922 - mae: 20.0242 - val_loss: 328.4187 - val_mae: 14.9357
# Epoch 3/100
# 12/12 [==============================] - 0s 4ms/step - loss: 372.6053 - mae: 17.3968 - val_loss: 233.4515 - val_mae: 12.3839
# Epoch 4/100
# 12/12 [==============================] - 0s 5ms/step - loss: 244.8345 - mae: 13.5124 - val_loss: 145.7491 - val_mae: 9.3119
# Epoch 5/100
# 12/12 [==============================] - 0s 5ms/step - loss: 125.6729 - mae: 8.8360 - val_loss: 107.9308 - val_mae: 8.7080
# Epoch 6/100
# 12/12 [==============================] - 0s 5ms/step - loss: 72.3522 - mae: 6.4488 - val_loss: 91.6087 - val_mae: 8.0516
# Epoch 7/100
# 12/12 [==============================] - 0s 5ms/step - loss: 54.6827 - mae: 5.5607 - val_loss: 62.4241 - val_mae: 6.5217
# Epoch 8/100
# 12/12 [==============================] - 0s 4ms/step - loss: 39.3036 - mae: 4.6121 - val_loss: 36.5541 - val_mae: 4.9116
# Epoch 9/100
# 12/12 [==============================] - 0s 5ms/step - loss:
# Epoch 38/100
# 12/12 [==============================] - 0s 4ms/step - loss: 11.0983 - mae: 2.3241 - val_loss: 4.5767 - val_mae: 1.5181
# Epoch 39/100
# 12/12 [==============================] - 0s 4ms/step - loss: 10.8612 - mae: 2.2791 - val_loss: 4.7871 - val_mae: 1.6204
# Epoch 40/100
# 12/12 [==============================] - 0s 4ms/step - loss: 10.8479 - mae: 2.2888 - val_loss: 4.2771 - val_mae: 1.5235
# Epoch 41/100
# 12/12 [==============================] - 0s 7ms/step - loss: 10.6550 - mae: 2.2545 - val_loss: 4.3059 - val_mae: 1.4769
# Epoch 42/100
# 12/12 [==============================] - 0s 12ms/step - loss: 10.4182 - mae: 2.2380 - val_loss: 3.9946 - val_mae: 1.4559
# Epoch 43/100
# 12/12 [==============================] - 0s 4ms/step - loss: 10.5105 - mae: 2.2605 - val_loss: 4.4305 - val_mae: 1.5432
# Epoch 44/100
# 12/12 [==============================] - 0s 5ms/step - loss: 10.1965 - mae: 2.2472 - val_loss: 3.9713 - val_mae: 1.3720
# Epoch 45/100
# 12/12 [==============================] - 0s 5ms/step - loss: 10.1697 - mae: 2.2240 - val_loss: 4.5300 - val_mae: 1.5955
# Epoch 46/100
# 12/12 [==============================] - 0s 4ms/step - loss: 10.0262 - mae: 2.2097 - val_loss: 4.3267 - val_mae: 1.5818
# Epoch 47/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.8774 - mae: 2.1999 - val_loss: 4.1477 - val_mae: 1.4520
# Epoch 48/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.8983 - mae: 2.1915 - val_loss: 4.7406 - val_mae: 1.5628
# Epoch 49/100
# 12/12 [==============================] - 0s 4ms/step - loss: 10.0358 - mae: 2.2178 - val_loss: 4.4995 - val_mae: 1.5884
# Epoch 50/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.9320 - mae: 2.2232 - val_loss: 3.7252 - val_mae: 1.3849
# Epoch 51/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.4454 - mae: 2.1703 - val_loss: 4.7754 - val_mae: 1.6842
# Epoch 52/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.7115 - mae: 2.2009 - val_loss: 4.1045 - val_mae: 1.4967
# Epoch 53/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.2562 - mae: 2.1438 - val_loss: 4.7045 - val_mae: 1.6108
# Epoch 54/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.2247 - mae: 2.1401 - val_loss: 4.4545 - val_mae: 1.5802
# Epoch 55/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.1024 - mae: 2.1198 - val_loss: 4.3781 - val_mae: 1.5808
# Epoch 56/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.0324 - mae: 2.1189 - val_loss: 5.0072 - val_mae: 1.6903
# Epoch 57/100
# 12/12 [==============================] - 0s 5ms/step - loss: 9.1133 - mae: 2.1380 - val_loss: 4.9218 - val_mae: 1.6711
# Epoch 58/100
# 12/12 [==============================] - 0s 5ms/step - loss: 8.9916 - mae: 2.1206 - val_loss: 4.3648 - val_mae: 1.5882
# Epoch 59/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.7280 - mae: 2.0919 - val_loss: 4.2730 - val_mae: 1.5795
# Epoch 60/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.6194 - mae: 2.0687 - val_loss: 4.5332 - val_mae: 1.6718
# Epoch 61/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.6106 - mae: 2.0680 - val_loss: 4.6339 - val_mae: 1.6503
# Epoch 62/100
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4865 - mae: 2.0628 - val_loss: 4.5909 - val_mae: 1.6691
# Epoch 63/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.4287 - mae: 2.0590 - val_loss: 4.3973 - val_mae: 1.6268
# Epoch 64/100
# 12/12 [==============================] - 0s 5ms/step - loss: 8.3737 - mae: 2.0324 - val_loss: 4.5905 - val_mae: 1.6414
# Epoch 65/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.2913 - mae: 2.0373 - val_loss: 4.3538 - val_mae: 1.6036
# Epoch 66/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.4664 - mae: 2.0661 - val_loss: 4.2607 - val_mae: 1.6447
# Epoch 67/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.3333 - mae: 2.0454 - val_loss: 4.8567 - val_mae: 1.7545
# Epoch 68/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.2793 - mae: 2.0810 - val_loss: 3.9527 - val_mae: 1.5522
# Epoch 69/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.1005 - mae: 2.0365 - val_loss: 4.7518 - val_mae: 1.7137
# Epoch 70/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.9586 - mae: 1.9715 - val_loss: 4.2847 - val_mae: 1.6771
# Epoch 71/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.7875 - mae: 1.9719 - val_loss: 4.6530 - val_mae: 1.7082
# Epoch 72/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.8315 - mae: 1.9912 - val_loss: 4.4014 - val_mae: 1.6682
# Epoch 73/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.7047 - mae: 1.9668 - val_loss: 4.7468 - val_mae: 1.7338
# Epoch 74/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.6109 - mae: 1.9449 - val_loss: 4.3220 - val_mae: 1.6857
# Epoch 75/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.5868 - mae: 1.9538 - val_loss: 4.6707 - val_mae: 1.7396
# Epoch 76/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.5115 - mae: 1.9418 - val_loss: 4.2097 - val_mae: 1.6109
# Epoch 77/100
# 12/12 [==============================] - 0s 5ms/step - loss: 7.5650 - mae: 1.9518 - val_loss: 4.3336 - val_mae: 1.7055
# Epoch 78/100
# 12/12 [==============================] - 0s 5ms/step - loss: 7.4713 - mae: 1.9524 - val_loss: 4.3423 - val_mae: 1.6707
# Epoch 79/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.3261 - mae: 1.9337 - val_loss: 4.5853 - val_mae: 1.7283
# Epoch 80/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.3851 - mae: 1.9397 - val_loss: 4.3883 - val_mae: 1.6824
# Epoch 81/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.2992 - mae: 1.9347 - val_loss: 4.1625 - val_mae: 1.6530
# Epoch 82/100
# 12/12 [==============================] - 0s 5ms/step - loss: 7.2015 - mae: 1.9146 - val_loss: 4.7923 - val_mae: 1.7991
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.2794 - mae: 1.9322 - val_loss: 4.7707 - val_mae: 1.8029
# Epoch 84/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.1662 - mae: 1.9357 - val_loss: 4.1708 - val_mae: 1.6365
# Epoch 85/100
# 12/12 [==============================] - 0s 5ms/step - loss: 7.1761 - mae: 1.8965 - val_loss: 4.7020 - val_mae: 1.7846
# Epoch 86/100
# 12/12 [==============================] - 0s 5ms/step - loss: 7.2186 - mae: 1.9196 - val_loss: 3.8806 - val_mae: 1.6230
# Epoch 87/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.9083 - mae: 1.8814 - val_loss: 4.6156 - val_mae: 1.7929
# Epoch 88/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.9545 - mae: 1.8766 - val_loss: 4.5299 - val_mae: 1.7230
# Epoch 89/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8232 - mae: 1.8709 - val_loss: 4.3000 - val_mae: 1.6768
# Epoch 90/100
# 12/12 [==============================] - 0s 5ms/step - loss: 6.7779 - mae: 1.8590 - val_loss: 4.6065 - val_mae: 1.7801
# Epoch 91/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8191 - mae: 1.8611 - val_loss: 3.9436 - val_mae: 1.6559
# Epoch 92/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.7152 - mae: 1.8492 - val_loss: 4.2233 - val_mae: 1.6719
# Epoch 93/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5958 - mae: 1.8357 - val_loss: 4.3444 - val_mae: 1.7135
# Epoch 94/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5708 - mae: 1.8322 - val_loss: 4.2397 - val_mae: 1.6879
# Epoch 95/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.7531 - mae: 1.8535 - val_loss: 4.1553 - val_mae: 1.6352
# Epoch 96/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5448 - mae: 1.8414 - val_loss: 4.3618 - val_mae: 1.7354
# Epoch 97/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4932 - mae: 1.8100 - val_loss: 4.7194 - val_mae: 1.8188
# Epoch 98/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4931 - mae: 1.8194 - val_loss: 4.3635 - val_mae: 1.7382
# Epoch 99/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.3743 - mae: 1.7908 - val_loss: 5.6858 - val_mae: 2.0289
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.3628 - mae: 1.7947 - val_loss: 4.2272 - val_mae: 1.6836

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
mse_nn, mae_nn= model.evaluate(X_test, y_test)
r2 = r2_score(y_test, y_pred)

print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
print('Accuracy:', r2*100)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 13.2915 - mae: 2.7437
# Mean squared error on test data:  13.291488647460938
# Mean absolute error on test data:  2.7436931133270264
# Accuracy: 86.88258498403277

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred, c='green')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
